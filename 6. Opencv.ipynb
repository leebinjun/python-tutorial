# %% [markdown]
# # 图像分类过程

# %% [markdown]
# ![jupyter](http://static.zybuluo.com/rianusr/bxxtw2jlzb7jm3rml3y6hws2/03-%E5%9B%BE%E5%83%8F%E5%88%86%E7%B1%BB%E8%BF%87%E7%A8%8B.png)

# %% [markdown]
# # 图像分类关键点

# %% [markdown]
# ## 数据准备

# %% [markdown]
# ![jupyter](http://static.zybuluo.com/rianusr/z2bkl8jxhr0flcbb4l9r5eh0/04-%E5%85%B3%E9%94%AE%E7%82%B9%EF%BC%9A%E6%95%B0%E6%8D%AE%E5%87%86%E5%A4%87.png)

# %% [markdown]
# ## 数据集划分

# %% [markdown]
# ![jupyter](http://static.zybuluo.com/rianusr/u48hes77gs7kwx4t21u29nau/04-%E5%85%B3%E9%94%AE%E7%82%B92%EF%BC%9A%E6%95%B0%E6%8D%AE%E9%9B%86%E5%88%92%E5%88%86.png)

# %% [markdown]
# ## 特征表示

# %% [markdown]
# ![jupyter](http://static.zybuluo.com/rianusr/16l7otuvswbqx0ix523akxl6/04-%E5%85%B3%E9%94%AE%E7%82%B93%EF%BC%9A%E7%89%B9%E5%BE%81%E8%A1%A8%E7%A4%BA.png)

# %% [markdown]
# ## 分类算法

# %% [markdown]
# ![jupyter](http://static.zybuluo.com/rianusr/egehxdfoblszf7reuls0zwwv/04-%E5%85%B3%E9%94%AE%E7%82%B94%EF%BC%9A%E5%88%86%E7%B1%BB%E7%AE%97%E6%B3%95.png)

# %% [markdown]
# ## 模型评估

# %% [markdown]
# ![jupyter](http://static.zybuluo.com/rianusr/t1m9trajgvfpq25h9wpmljox/04-%E5%85%B3%E9%94%AE%E7%82%B95%EF%BC%9A%E6%A8%A1%E5%9E%8B%E8%AF%84%E4%BC%B0.png)

# %% [markdown]
# # 图像特征 - 颜色直方图

# %% [markdown]
# ## RGB 颜色空间

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

pic_file='pictures/flower.jpg'
img_bgr = cv2.imread(pic_file,cv2.IMREAD_COLOR) # BGR

# 分别获取三个通道的ndarray数据
img_b=img_bgr[...,0]
img_g=img_bgr[...,1]
img_r=img_bgr[...,2]

# 分通道显示图片
fig = plt.gcf()
fig.set_size_inches(10,10)

plt.subplot(221) # 2 行 2 列 第 2 子图
plt.imshow(np.flip(img_bgr,axis=2))# axis =0 垂直翻转 =1 水平翻转
plt.axis('off') # 不显示坐标
plt.title('Image')

plt.subplot(222)
plt.imshow(img_r,cmap='gray') # r 层 并 灰度化
plt.axis('off')
plt.title('R')

plt.subplot(223)
plt.imshow(img_g,cmap='gray')
plt.axis('off')
plt.title('G')

plt.subplot(224)
plt.imshow(img_b,cmap='gray')
plt.axis('off')
plt.title('B')
plt.show()

# %% [markdown]
# ## HSV颜色空间

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

pic_file='pictures/flower.jpg'
img_bgr = cv2.imread(pic_file,cv2.IMREAD_COLOR)

# 通过cvtColor()方法转换颜色空间
img_hsv = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2HSV)
img_h = img_hsv[...,0]
img_s = img_hsv[...,1]
img_v = img_hsv[...,2]

'''分通道显示图片'''
fig = plt.gcf()
fig.set_size_inches(10,10)

plt.subplot(221)
plt.imshow(img_hsv)
plt.axis('off')
plt.title('HSV')

plt.subplot(222)
plt.imshow(img_h,cmap='gray')
plt.axis('off')
plt.title('H')

plt.subplot(223)
plt.imshow(img_s,cmap='gray')
plt.axis('off')
plt.title('S')

plt.subplot(224)
plt.imshow(img_v,cmap='gray')
plt.axis('off')
plt.title('V')
plt.show()

# %% [markdown]
# ## L*a*b*颜色空间

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

pic_file='pictures/flower.jpg'
img_bgr = cv2.imread(pic_file,cv2.IMREAD_COLOR)

img_lab = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2LAB)
img_ls = img_lab[...,0]
img_as = img_lab[...,1]
img_bs = img_lab[...,2]

'''分通道显示图片'''
fig = plt.gcf()
fig.set_size_inches(10,10)

plt.subplot(221)
plt.imshow(img_lab)
plt.axis('off')
plt.title('L*a*b')

plt.subplot(222)
plt.imshow(img_ls,cmap='gray')
plt.axis('off')
plt.title('L*')


plt.subplot(223)
plt.imshow(img_ls,cmap='gray')
plt.axis('off')
plt.title('a*')

plt.subplot(224)
plt.imshow(img_ls,cmap='gray')
plt.axis('off')
plt.title('b*')

plt.show()

# %% [markdown]
# ## 灰度图

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

pic_file='pictures/flower.jpg'
img_bgr = cv2.imread(pic_file,cv2.IMREAD_COLOR)

img_gray = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2GRAY)

fig = plt.gcf()
fig.set_size_inches(5,5)
plt.imshow(img_gray,cmap='gray')
plt.axis('off')
plt.title('Gray')
plt.show()
